# %% [markdown]
# # What is EDA
#
# Exploratory Data Analysis refers to the critical process of performing initial investigation on data so as to discover patterns,
# to spot anomalies, to test hypothesis and to check assumptions with the help of summary statistics and graphical representations

# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Reading the data

# %%
df=pd.read_csv(r'C:\Users\Anand Mishra\Downloads\Indian_railway1.csv')
df
# Out:
#        Train No    Train Name SEQ Station Code  Station Name Arrival time  \
# 0           107  SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 1           107  SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 2           107  SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 3           107  SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 4           108  VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
# ...         ...           ...  ..          ...           ...          ...
# 186119    99908           EMU   8         AKRD        AKURDI     23:30:00
# 186120    99908           EMU   9         DEHR     DEHU ROAD     23:35:00
# 186121    99908           EMU  10         BGWI     BEGDAEWAI     23:39:00
# 186122    99908           EMU  11         GRWD     GHORAWADI     23:41:00
# 186123    99908           EMU  12          TGN      TALEGAON     23:50:00
#
#        Departure Time Distance Source Station Source Station Name  \
# ...

# %%
df=pd.read_csv(r'C:\Users\Anand Mishra\Downloads\Indian_railway1.csv', index_col=0)
df
# Out:
#             Train Name SEQ Station Code  Station Name Arrival time  \
# Train No
# 107       SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 107       SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 107       SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 107       SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 108       VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
# ...                ...  ..          ...           ...          ...
# 99908              EMU   8         AKRD        AKURDI     23:30:00
# 99908              EMU   9         DEHR     DEHU ROAD     23:35:00
# 99908              EMU  10         BGWI     BEGDAEWAI     23:39:00
# 99908              EMU  11         GRWD     GHORAWADI     23:41:00
# 99908              EMU  12          TGN      TALEGAON     23:50:00
#
#          Departure Time Distance Source Station Source Station Name  \
# Train No
# 107            10:25:00        0            SWV     SAWANTWADI ROAD
# ...

# %% [markdown]
# # To view all data

# %%
df
# Out:
#             Train Name SEQ Station Code  Station Name Arrival time  \
# Train No
# 107       SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 107       SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 107       SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 107       SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 108       VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
# ...                ...  ..          ...           ...          ...
# 99908              EMU   8         AKRD        AKURDI     23:30:00
# 99908              EMU   9         DEHR     DEHU ROAD     23:35:00
# 99908              EMU  10         BGWI     BEGDAEWAI     23:39:00
# 99908              EMU  11         GRWD     GHORAWADI     23:41:00
# 99908              EMU  12          TGN      TALEGAON     23:50:00
#
#          Departure Time Distance Source Station Source Station Name  \
# Train No
# 107            10:25:00        0            SWV     SAWANTWADI ROAD
# ...

# %% [markdown]
# # Describe
# This function returns the count, mean, standard deviation, minimum and maximum values and the quantiles of the data.

# %%
df.describe()
# Out:
#          Train Name     SEQ Station Code Station Name Arrival time  \
# count        186124  186124       186124       186124       186119
# unique         7585     235         8151         8100         1443
# top     MSB-TBM EMU       2         CSMT   CST-MUMBAI     00:00:00
# freq           2436    7186         1027         1027         2002
#
#        Departure Time Distance Source Station Source Station Name  \
# count          186119   186119         186114              186114
# unique           1444     3829            926                 921
# top          00:00:00        0            HWH          HOWRAH JN.
# freq             1969     7191           7977                7977
#
#        Destination Station Destination Station Name
# count               186114                   186114
# unique                 928                      923
# top                    HWH               HOWRAH JN.
# freq                  7840                     7840

# %% [markdown]
# # print all statistical information

# %%
df.describe(include='all')
# Out:
#          Train Name     SEQ Station Code Station Name Arrival time  \
# count        186124  186124       186124       186124       186119
# unique         7585     235         8151         8100         1443
# top     MSB-TBM EMU       2         CSMT   CST-MUMBAI     00:00:00
# freq           2436    7186         1027         1027         2002
#
#        Departure Time Distance Source Station Source Station Name  \
# count          186119   186119         186114              186114
# unique           1444     3829            926                 921
# top          00:00:00        0            HWH          HOWRAH JN.
# freq             1969     7191           7977                7977
#
#        Destination Station Destination Station Name
# count               186114                   186114
# unique                 928                      923
# top                    HWH               HOWRAH JN.
# freq                  7840                     7840

# %% [markdown]
# # info()
# print the information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186124 entries, 107 to 99908
# Data columns (total 11 columns):
# Train Name                  186124 non-null object
# SEQ                         186124 non-null object
# Station Code                186124 non-null object
# Station Name                186124 non-null object
# Arrival time                186119 non-null object
# Departure Time              186119 non-null object
# Distance                    186119 non-null object
# Source Station              186114 non-null object
# Source Station Name         186114 non-null object
# Destination Station         186114 non-null object
# Destination Station Name    186114 non-null object
# dtypes: object(11)
# memory usage: 17.0+ MB

# %% [markdown]
# # head()
# To print top 5 rows

# %%
df.head()
# Out:
#             Train Name SEQ Station Code  Station Name Arrival time  \
# Train No
# 107       SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 107       SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 107       SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 107       SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 108       VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
#
#          Departure Time Distance Source Station Source Station Name  \
# Train No
# 107            10:25:00        0            SWV     SAWANTWADI ROAD
# 107            11:08:00       32            SWV     SAWANTWADI ROAD
# 107            11:30:00       49            SWV     SAWANTWADI ROAD
# 107            00:00:00       78            SWV     SAWANTWADI ROAD
# 108            20:30:00        0            MAO         MADGOAN JN.
#
#          Destination Station Destination Station Name
# Train No
# 107                      MAO              MADGOAN JN.
# ...

# %% [markdown]
# # tail()
# To print bottom 5 rows

# %%
df.tail()
# Out:
#          Train Name SEQ Station Code Station Name Arrival time Departure Time  \
# Train No
# 99908           EMU   8         AKRD       AKURDI     23:30:00       23:31:00
# 99908           EMU   9         DEHR    DEHU ROAD     23:35:00       23:36:00
# 99908           EMU  10         BGWI    BEGDAEWAI     23:39:00       23:40:00
# 99908           EMU  11         GRWD    GHORAWADI     23:41:00       23:42:00
# 99908           EMU  12          TGN     TALEGAON     23:50:00       00:00:00
#
#          Distance Source Station Source Station Name Destination Station  \
# Train No
# 99908          19           PUNE            PUNE JN.                 TGN
# 99908          24           PUNE            PUNE JN.                 TGN
# 99908          28           PUNE            PUNE JN.                 TGN
# 99908          31           PUNE            PUNE JN.                 TGN
# 99908          34           PUNE            PUNE JN.                 TGN
#
#          Destination Station Name
# ...

# %% [markdown]
# # shape
# To ckeck how many row and colunm

# %%
df.shape
# Out:
# (186124, 11)

# %% [markdown]
# # dtypes
# To check data type of attribute

# %%
df.dtypes
# Out:
# Train Name                  object
# SEQ                         object
# Station Code                object
# Station Name                object
# Arrival time                object
# Departure Time              object
# Distance                    object
# Source Station              object
# Source Station Name         object
# Destination Station         object
# Destination Station Name    object
# dtype: object

# %% [markdown]
# # index
# To print the index

# %%
df.index
# Out:
# Index([  '107',   '107',   '107',   '107',   '108',   '108',   '108',   '108',
#          '128',   '128',
#        ...
#        '99908', '99908', '99908', '99908', '99908', '99908', '99908', '99908',
#        '99908', '99908'],
#       dtype='object', name='Train No', length=186124)

# %% [markdown]
# # To check is ther any missing value

# %%
df.isna()
# Out:
#           Train Name    SEQ  Station Code  Station Name  Arrival time  \
# Train No
# 107            False  False         False         False         False
# 107            False  False         False         False         False
# 107            False  False         False         False         False
# 107            False  False         False         False         False
# 108            False  False         False         False         False
# ...              ...    ...           ...           ...           ...
# 99908          False  False         False         False         False
# 99908          False  False         False         False         False
# 99908          False  False         False         False         False
# 99908          False  False         False         False         False
# 99908          False  False         False         False         False
#
#           Departure Time  Distance  Source Station  Source Station Name  \
# Train No
# ...

# %% [markdown]
# # Sum of missing value

# %%
df.isna().sum()
# Out:
# Train Name                   0
# SEQ                          0
# Station Code                 0
# Station Name                 0
# Arrival time                 5
# Departure Time               5
# Distance                     5
# Source Station              10
# Source Station Name         10
# Destination Station         10
# Destination Station Name    10
# dtype: int64

# %% [markdown]
# # Sum of null value

# %%
df.isnull().sum()
# Out:
# Train Name                   0
# SEQ                          0
# Station Code                 0
# Station Name                 0
# Arrival time                 5
# Departure Time               5
# Distance                     5
# Source Station              10
# Source Station Name         10
# Destination Station         10
# Destination Station Name    10
# dtype: int64

# %% [markdown]
# # To check the duplicated value

# %%
df.duplicated()
# Out:
# Train No
# 107      False
# 107      False
# 107      False
# 107      False
# 108      False
#          ...
# 99908    False
# 99908    False
# 99908    False
# 99908    False
# 99908    False
# Length: 186124, dtype: bool

# %% [markdown]
# # Number of unique values in data set

# %%
df.nunique()
# Out:
# Train Name                  7585
# SEQ                          235
# Station Code                8151
# Station Name                8100
# Arrival time                1443
# Departure Time              1444
# Distance                    3829
# Source Station               926
# Source Station Name          921
# Destination Station          928
# Destination Station Name     923
# dtype: int64

# %% [markdown]
# # To find unique station name

# %%
df['Station Name'].unique()
# Out:
# array(['SAWANTWADI R', 'THIVIM', 'KARMALI', ..., 'MANKHURD', 'CHEMBUR',
#        'NERUL'], dtype=object)

# %% [markdown]
# # To find Destination Station Name

# %%
df['Destination Station Name'].unique()
# Out:
# array(['MADGOAN JN.', 'SAWANTWADI ROAD',
#        'CHHATRAPATI SHAHU MAHARAJ TERMINUS', 'DELHI-SAFDAR JANG',
#        'VARANASI JN.', 'SHRI MATA VAISHNO DEVI KATRA', 'LUCKNOW JN.',
#        'SIRSA', 'AMBALA CANTT JN', 'BATHINDA JN', 'PATIALA', 'PANJIPARA',
#        'AMRITSAR JN.', 'NAGPUR JN.(CR)', 'LOKMANYA TILAK TERMINUS',
#        'KARMALI', 'AJNI', 'CST-MUMBAI', 'MANGALORE JN', 'PUNE JN.',
#        'KHADKI', 'JABALPUR', 'BANDRA TERMINUS', 'ATARI JN',
#        'SANTRAGACHI JN.', 'BHOPAL', 'REWA', 'SILCHAR', 'POLLACHI',
#        'PALANI', 'JAIPUR JN.', 'HYDERABAD DECCAN', 'RAJKOT',
#        'CHENNAI CENTRAL', 'HATIA', 'PURI', 'KOLKATA', 'DHANBAD JN.',
#        'ASANSOL MAIN', 'KUSUNDA', 'PHULWARTANR', 'SONARDIH',
#        'ANAND VIHAR TERMINAL', 'JASIDIH JN.', 'DELHI JN.',
#        'HAZRAT NIZAMUDDIN JN', 'HARIDWAR JN', 'BIKANER JN.',
#        'SHRI GANGANAGAR', 'HANUMANGARH JN.', 'SADULPUR JN',
#        'SURATGARH JN.', 'MAKRANA JN.', 'PARVATSAR CITY', 'JODHPUR JN.',
# ...

# %% [markdown]
# # Count the SEQ

# %%
df.SEQ.value_counts()
# Out:
# 2      7186
# 1      7186
# 3      6174
# 4      6072
# 5      5885
#        ...
# 117       1
# 116       1
# 115       1
# 114       1
# 118       1
# Name: SEQ, Length: 235, dtype: int64

# %% [markdown]
# # To view the record of LUCKNOW JN.

# %%
d=df[df['Station Name']=='LUCKNOW JN.']
d
# Out:
#             Train Name SEQ Station Code Station Name Arrival time  \
# Train No
# 401       BSB BHARATDA   7          LKO  LUCKNOW JN.     23:50:00
# 421       LKO-SVDK FTR   1          LKO  LUCKNOW JN.     23:00:00
# 422       SVDK-LKO FTR   5          LKO  LUCKNOW JN.     14:30:00
# 5065           CPR-LJN  15          LJN  LUCKNOW JN.     08:15:00
# 5066       LJN-CPR-EXP   1          LJN  LUCKNOW JN.     20:25:00
# ...                ...  ..          ...          ...          ...
# 64275     BBK-LJN MEMU  10          LJN  LUCKNOW JN.     21:45:00
# 64281     SLN-LKO MEMU  18          LKO  LUCKNOW JN.     11:00:00
# 64282     LKO-SLN MEMU   1          LKO  LUCKNOW JN.     16:45:00
# 74201      PBH-LKO DMU  25          LKO  LUCKNOW JN.     10:45:00
# 74202      LKO/PBH DMU   1          LKO  LUCKNOW JN.     16:30:00
#
#          Departure Time Distance Source Station           Source Station Name  \
# Train No
# ...

# %% [markdown]
# # To count number of Destination Station Name

# %%
d['Destination Station Name'].value_counts()
# Out:
# LUCKNOW JN.             66
# GORAKHPUR JN.           23
# VARANASI JN.            18
# ANAND VIHAR TERMINAL    15
# NEW DELHI               14
#                         ..
# DANAPUR                  1
# GHAZIPUR CITY            1
# UDAIPUR CITY             1
# NAHARLAGUN               1
# TRIVANDRUM CENTRAL       1
# Name: Destination Station Name, Length: 103, dtype: int64

# %% [markdown]
# # To check data is aligned in a tabular fashion in rows and columns.

# %%
dt=pd.DataFrame(df)
dt
# Out:
#             Train Name SEQ Station Code  Station Name Arrival time  \
# Train No
# 107       SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 107       SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 107       SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 107       SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 108       VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
# ...                ...  ..          ...           ...          ...
# 99908              EMU   8         AKRD        AKURDI     23:30:00
# 99908              EMU   9         DEHR     DEHU ROAD     23:35:00
# 99908              EMU  10         BGWI     BEGDAEWAI     23:39:00
# 99908              EMU  11         GRWD     GHORAWADI     23:41:00
# 99908              EMU  12          TGN      TALEGAON     23:50:00
#
#          Departure Time Distance Source Station Source Station Name  \
# Train No
# 107            10:25:00        0            SWV     SAWANTWADI ROAD
# ...

# %% [markdown]
# # To sort the value of Destination Station Name TO TOP 15

# %%
dn=d.sort_values('Destination Station Name',ascending=False).head(15)
dn
# Out:
#             Train Name SEQ Station Code Station Name Arrival time  \
# Train No
# 15015     GKP- YPR EXP   4          LJN  LUCKNOW JN.     11:30:00
# 12540     LKO-YPR EXPR   1          LKO  LUCKNOW JN.     20:00:00
# 12591      GKP-SBC EXP   8          LJN  LUCKNOW JN.     11:30:00
# 22684     LKO-YPR WEEK   1          LKO  LUCKNOW JN.     00:00:00
# 15023      GKP-YPR-EXP   5          LKO  LUCKNOW JN.     15:55:00
# 14266     DDN BSB EXPR  32          LKO  LUCKNOW JN.     07:45:00
# 19167     SABARMATI EX  45          LKO  LUCKNOW JN.     00:50:00
# 14866     MARUDHAR EXP  26          LKO  LUCKNOW JN.     02:50:00
# 14864     MARUDHAR EXP  27          LKO  LUCKNOW JN.     02:50:00
# 14854     MARUDHAR EXP  27          LKO  LUCKNOW JN.     02:50:00
# 12238     JAT-BSB EXP.   9          LKO  LUCKNOW JN.     07:10:00
# 22408     ANVT-BSB GAR   4          LKO  LUCKNOW JN.     02:25:00
# 14258     KASHI V EXPR  18          LKO  LUCKNOW JN.     21:35:00
# ...

# %% [markdown]
# # Extract data
# Extract data of the Destination Station Name NEW DELHI to check how many train NEW DELHI

# %%
nd=dt.loc[(dt['Destination Station Name']=='NEW DELHI')]
nd
# Out:
#             Train Name SEQ Station Code  Station Name Arrival time  \
# Train No
# 9005       BCT NDLS BI   1          BCT  MUMBAI CENTR     16:00:00
# 9005       BCT NDLS BI   2          BRC  VADODARA JN.     20:27:00
# 9005       BCT NDLS BI   3         KOTA          KOTA     02:35:00
# 9005       BCT NDLS BI   4         NDLS     NEW DELHI     07:55:00
# 12001     BPL - NDLS S   1          HBJ     HABIBGANJ     15:00:00
# ...                ...  ..          ...           ...          ...
# 64912     ROK-NDLS MEM  13          SSB  SHAKUR BASTI     08:38:00
# 64912     ROK-NDLS MEM  14         DBSI    DAYA BASTI     08:47:00
# 64912     ROK-NDLS MEM  15         VVKP  VIVEKANANDPU     08:51:00
# 64912     ROK-NDLS MEM  16          DKZ  DELHI-KISHAN     08:56:00
# 64912     ROK-NDLS MEM  17         NDLS     NEW DELHI     09:15:00
#
#          Departure Time Distance Source Station Source Station Name  \
# Train No
# 9005           16:00:00        0            BCT      MUMBAI CENTRAL
# ...

# %% [markdown]
# #  Extract data
# Extract data of the Source Station Name

# %%
nd=dt.loc[(dt['Source Station Name']=='MUMBAI CENTRAL')]
nd
# Out:
#             Train Name SEQ Station Code  Station Name Arrival time  \
# Train No
# 9005       BCT NDLS BI   1          BCT  MUMBAI CENTR     16:00:00
# 9005       BCT NDLS BI   2          BRC  VADODARA JN.     20:27:00
# 9005       BCT NDLS BI   3         KOTA          KOTA     02:35:00
# 9005       BCT NDLS BI   4         NDLS     NEW DELHI     07:55:00
# 12009     SHATABDI EXP   1          BCT  MUMBAI CENTR     06:25:00
# ...                ...  ..          ...           ...          ...
# 59441     AHMEDABAD PA  70          BJD  BAREJADI NAN     13:43:00
# 59441     AHMEDABAD PA  71          GER      GERATPUR     14:00:00
# 59441     AHMEDABAD PA  72          VTA         VATVA     14:06:00
# 59441     AHMEDABAD PA  73          MAN     MANINAGAR     14:13:00
# 59441     AHMEDABAD PA  74          ADI     AHMEDABAD     14:55:00
#
#          Departure Time Distance Source Station Source Station Name  \
# Train No
# 9005           16:00:00        0            BCT      MUMBAI CENTRAL
# ...

# %% [markdown]
# # Extract data
# Train schedule for MUMBAI CENTRAL to NEW DELHI

# %%
nd=dt.loc[(dt['Source Station Name']=='MUMBAI CENTRAL') & (dt['Destination Station Name']=='NEW DELHI')]
nd
# Out:
#             Train Name SEQ Station Code  Station Name Arrival time  \
# Train No
# 9005       BCT NDLS BI   1          BCT  MUMBAI CENTR     16:00:00
# 9005       BCT NDLS BI   2          BRC  VADODARA JN.     20:27:00
# 9005       BCT NDLS BI   3         KOTA          KOTA     02:35:00
# 9005       BCT NDLS BI   4         NDLS     NEW DELHI     07:55:00
# 12951     MUMBAI RAJDH   1          BCT  MUMBAI CENTR     17:00:00
# 12951     MUMBAI RAJDH   2          BVI       BORIVLI     17:30:00
# 12951     MUMBAI RAJDH   3           ST         SURAT     19:53:00
# 12951     MUMBAI RAJDH   4          BRC  VADODARA JN.     21:18:00
# 12951     MUMBAI RAJDH   5          RTM     RATLAM JN     00:37:00
# 12951     MUMBAI RAJDH   6          NAD      NAGDA JN     01:18:00
# 12951     MUMBAI RAJDH   7         KOTA          KOTA     03:20:00
# 12951     MUMBAI RAJDH   8         NDLS     NEW DELHI     08:35:00
# 22209     NDLS DURONTO   1          BCT  MUMBAI CENTR     23:15:00
# ...

# %% [markdown]
# # unique()
# Use to find station name from Station Name row

# %%
nd['Station Name'].unique()
# Out:
# array(['MUMBAI CENTR', 'VADODARA JN.', 'KOTA', 'NEW DELHI', 'BORIVLI',
#        'SURAT', 'RATLAM JN', 'NAGDA JN'], dtype=object)

# %% [markdown]
# # Data Visualization
# Plot a graph of Indian train dataset

# %%
plt.bar(nd['Train Name'],nd['Station Name'])
plt.title('Train Name vs Station Name',fontsize=20,color='red')
plt.xlabel('Name of the train',fontsize=20)
plt.ylabel('Name of the station',fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# # relplot()
# This is a figure-level function for visualizing statistical relationships using two common approaches

# %%
plt.figure(figsize=(20,22))
sns.set_style('darkgrid')
sns.relplot(x='Distance',y='Arrival time',hue='Station Name',data=nd)
plt.show()

# %% [markdown]
# # Countplot()
# A countplot is kind of likea histogram or a bar graph for some categorical area. It simply shows the number of occurrences of an item based on a certain type of category.

# %%
plt.figure(figsize=(10,13))
sns.countplot(x='Station Name',data=nd,palette='coolwarm')
plt.show()

# %% [markdown]
# # Pie plot()
# Pie charts show the size of items (called wedge) in one data series,

# %%
plt.figure(figsize=(5,9))
plt.title('Source Station Name',fontsize=20)
dn['Source Station Name'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# # kdeplot()
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset,
# analagous to a histogram. KDE represents the data using a continuous probability density
# curve in one or more dimensions.

# %%
sns.kdeplot(nd['Distance'],nd['SEQ'],color='green',shade=True)
plt.show()

# %% [markdown]
# # pairplot()
# To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function.
# This shows the relationship for (n, 2) combination of variable in a DataFrame as a matrix of
# plots and the diagonal plots are the univariate plots.

# %%
sns.pairplot(nd)
plt.show()

# %% [markdown]
# # Pairplot()

# %%
sns.pairplot(nd,diag_kind='kde',hue='Station Name')
plt.show()

# %% [markdown]
# # swarm plot()
# is very similar to a strip plot, yet the locations of points are adjusted automatically to avoid overlap even if the jitter value is not applied.

# %%
sns.swarmplot(x='Distance',y='SEQ',hue='Station Name',dodge=True,data=nd)
plt.show()

# %% [markdown]
# # CONCLUSION
#
# DATA SET: Indian Railway
#
#
# Analysis:
#
# My Analysis of Indain Railways with the Data Set. It Clearly shows that we can find train as per our need on the time and there are rows with Train Name and Station Name from where anyone can select Train from Stantion start there journey from Source Station Name to Destination Station Name which clrearly shows the name of the station.
#
# In the Data set clearly mentioned Train No, Train Name, SEQ, Station Code, Arrival time, Departure Time, Distance, Source Station, Source Station Name, Destionation Station, Destination Station Name with all rows we can find Train. There are some part of visualization with that help we can plot data set in nice visual.
